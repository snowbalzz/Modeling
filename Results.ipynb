# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('results.csv', index_col=0)
df = df.drop(index=15)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1m/n8hnbtc1343_hbndzzhc9d300000gn/T/ipykernel_13198/929281446.py in <module>
#       1 df = pd.read_csv('results.csv', index_col=0)
#       2 df = df.drop(index=15)
# ----> 3 df = df('MAE').str.to_float()
#       4 df
#
# TypeError: 'DataFrame' object is not callable

# %%
plt.scatter(df["MSE"], df["MAE"])
plt.xlabel("MSE")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 1 to 14
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Days    14 non-null     int64
#  1   MSE     14 non-null     float64
#  2   MAE     14 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
plt.title("MSE", loc = 'left')
plt.plot(df["Days"], df["MSE"])
plt.show()

# %%
plt.title("MAE", loc = 'left')
plt.plot(df["Days"], df["MAE"])
plt.show()
