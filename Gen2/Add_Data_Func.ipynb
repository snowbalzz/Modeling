# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import persons R

# %% [markdown]
# ## Data frames

# %%
# Add Data frame
df0 = pd.read_csv('../../csv/Combined_Data_Frame.csv', index_col=0)
df0.reset_index(inplace=True)
df0['Record Date'] = pd.to_datetime(df0['Record Date'])
df1 = pd.read_csv('../../csv/Radiation.csv', index_col=0)

# %%
df0
# Out:
#      Record Date  Total Demand  Wind Speed  Air Temperature(Apparent)  \
# 0     2021-01-01       63342.0       14.50                      11.32
# 1     2021-01-02       67819.0       21.53                      11.35
# 2     2021-01-03       67018.0       20.20                      10.32
# 3     2021-01-04       75574.0       13.58                      10.49
# 4     2021-01-05       78002.0       12.05                       8.99
# ...          ...           ...         ...                        ...
# 1455  2018-12-27       68436.0        7.42                      13.59
# 1456  2018-12-28       68179.0       14.38                      14.28
# 1457  2018-12-29       64849.0       14.44                      15.05
# 1458  2018-12-30       61282.0       17.58                      16.38
# 1459  2018-12-31       62108.0       15.80                      17.68
#
#       Air Temperature  Cloud Coverage
# 0                0.95           74.92
# 1               -0.01           68.10
# 2                0.07           85.41
# 3                0.10           87.49
# 4               -0.14           88.71
# ...               ...             ...
# 1455             2.40           71.22
# 1456             2.36           53.98
# 1457             2.04           39.59
# 1458             3.42           50.86
# 1459             4.32           57.01
#
# [1460 rows x 6 columns]

# %%
df1
# Out:
#           2015   2016   2017   2018   2019   2020   2021   2022
# [01-01]    NaN    NaN  63.73    NaN  42.60    NaN  50.79    NaN
# [02-01]    NaN  33.57  50.46  19.66  60.38  48.08  44.90  50.67
# [03-01]    NaN  29.93  72.64  34.16  71.05  32.49  42.45  39.20
# [04-01]    NaN  46.22  48.46  18.49  68.17  58.01  37.06  37.52
# [05-01]    NaN  46.01  66.15  40.68  52.93  67.70  42.72  63.00
# ...        ...    ...    ...    ...    ...    ...    ...    ...
# [27-12]  62.41  41.91  32.47  56.83  39.28  47.75  30.87    NaN
# [28-12]  61.99  69.52  53.97  55.43  59.52  23.50  21.83    NaN
# [29-12]  52.49  71.60  28.04  61.70  62.85  35.86  11.95    NaN
# [30-12]  62.84  71.95  22.61  55.69  70.01  41.38  47.78    NaN
# [31-12]  42.22  71.40  52.09  50.26  64.63  43.91  65.23    NaN
#
# [365 rows x 8 columns]

# %% [markdown]
# ### Selected years

# %%
# Selection of 4 Years
years = ['2018', '2019', '2020', '2021']

# %% [markdown]
# ### Function

# %%
def selector(year, df, name):

    dc = df[[year]].copy()
    dc.reset_index(inplace=True)
    dc = dc.rename(columns = {'index':'Record Date'})

    dc['Record Date'] = pd.to_datetime(dc['Record Date'], format="[%d-%m]")
    dc.rename(columns = {year:name}, inplace = True)

    dc['Record Date'] = dc['Record Date'].astype('string')
    dc['Record Date'] = dc['Record Date'].str.replace('1900', year)
    dc['Record Date'] = pd.to_datetime(dc['Record Date'], format="%Y-%m-%d")

    return dc

def shuffleData(years, df, name):
    
    selectedList = [];

    for i in years:
        selected = selector(i, df, name)
        selectedList.append(selected)

    #Contact using Iteration
    ff = pd.concat([selectedList[3], selectedList[2],  selectedList[1],  selectedList[0]])

    ff.reset_index(inplace=True)
    ff.drop('index', axis=1, inplace=True)
    
    return ff

# df - New data from EnnAppSys system (Daily)
# mf - Main data frame to which you append the new data
def mergeData(years, df, mf, name):
    
    sf = shuffleData(years, df, name)
    finalMerge = pd.merge(mf, sf, on='Record Date', how='right' )

    return finalMerge

# %% [markdown]
# ### Run Code

# %%
df = mergeData(years, df1, df0, "Radiation")
df
# Out:
#      Record Date  Total Demand  Wind Speed  Air Temperature(Apparent)  \
# 0     2021-01-01       63342.0       14.50                      11.32
# 1     2021-01-02       67819.0       21.53                      11.35
# 2     2021-01-03       67018.0       20.20                      10.32
# 3     2021-01-04       75574.0       13.58                      10.49
# 4     2021-01-05       78002.0       12.05                       8.99
# ...          ...           ...         ...                        ...
# 1455  2018-12-27       68436.0        7.42                      13.59
# 1456  2018-12-28       68179.0       14.38                      14.28
# 1457  2018-12-29       64849.0       14.44                      15.05
# 1458  2018-12-30       61282.0       17.58                      16.38
# 1459  2018-12-31       62108.0       15.80                      17.68
#
#       Air Temperature  Cloud Coverage  Radiation
# 0                0.95           74.92      50.79
# 1               -0.01           68.10      44.90
# 2                0.07           85.41      42.45
# 3                0.10           87.49      37.06
# 4               -0.14           88.71      42.72
# ...               ...             ...        ...
# 1455             2.40           71.22      56.83
# 1456             2.36           53.98      55.43
# 1457             2.04           39.59      61.70
# 1458             3.42           50.86      55.69
# 1459             4.32           57.01      50.26
#
# [1460 rows x 7 columns]
